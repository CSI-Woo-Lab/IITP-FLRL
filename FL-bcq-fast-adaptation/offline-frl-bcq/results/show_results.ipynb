# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
res0 = np.load("BCQ_Navi-Acc-Lidar-Obs-Task0_easy-v0_0_phi_0.05.npy")
res1 = np.load("CQL_Navi-Acc-Lidar-Obs-Task0_easy-v0_0.npy")
res2 = np.load("DDPG_offline_Navi-Acc-Lidar-Obs-Task0_easy-v0_0.npy")
res3 = np.load("behavioral_Navi-Acc-Lidar-Obs-Task0_easy-v0_0.npy")

plt.plot(res3, label="DDPG (online)")
plt.plot(res2, label="DDPG (offline)")
plt.plot(res1, label="CQL")
plt.plot(res0, label="BCQ")

plt.legend()
plt.ylim(-14, 9)
plt.xlim(0, 120)
plt.xlabel("timestep (5e3)")
plt.ylabel("score")
plt.title("Learning Graph (Single Model)")
# Out:
# Text(0.5, 1.0, 'Learning Graph (Single Model)')

# %%
res0 = np.load("BCQ_Navi-Acc-Lidar-Obs-Task0_easy-v0_0_phi_0.05.npy")
res1 = np.load("BCQ_Navi-Acc-Lidar-Obs-Task1_easy-v0_0.npy")
res2 = np.load("BCQ_Navi-Acc-Lidar-Obs-Task2_easy-v0_0.npy")
res3 = np.load("BCQ_Navi-Acc-Lidar-Obs-Task3_easy-v0_0.npy")

plt.plot(res0, label="env0")
plt.plot(res1, label="env1")
plt.plot(res2, label="env2")
plt.plot(res3, label="env3")

plt.legend()
# plt.ylim(-13, 9)
plt.xlim(0, 10)
plt.xlabel("timestep (5e3)")
plt.ylabel("score")
plt.title("BCQ")
# Out:
# Text(0.5, 1.0, 'BCQ')

# %%
res = np.load("CQL_Navi-Acc-Lidar-Obs-Task0_easy-v0_0.npy")
plt.plot(res)
plt.ylim(-13, 9)
plt.xlabel("timestep (5e3)")
plt.ylabel("score")
plt.title("CQL")
# Out:
# Text(0.5, 1.0, 'CQL')

# %%
res = np.load("DDPG_offline_Navi-Acc-Lidar-Obs-Task0_easy-v0_0.npy")
plt.plot(res)
plt.ylim(-13, 9)
plt.xlabel("timestep (5e3)")
plt.ylabel("score")
plt.title("DDPG_offline")
# Out:
# Text(0.5, 1.0, 'DDPG_offline')

# %%
res0 = np.load("behavioral_Navi-Acc-Lidar-Obs-Task0_easy-v0_0.npy")
res1 = np.load("behavioral_Navi-Acc-Lidar-Obs-Task1_easy-v0_0.npy")
res2 = np.load("behavioral_Navi-Acc-Lidar-Obs-Task2_easy-v0_0.npy")
# res3 = np.load("behavioral_Navi-Acc-Lidar-Obs-Task3_easy-v0_0.npy")
plt.plot(res0, label="env0")
plt.plot(res1, label="env1")
plt.plot(res2, label="env2")
# plt.plot(res3, label="env3")
plt.legend()
# plt.ylim(-13, 9)
plt.xlim(0, 10)
plt.xlabel("timestep (5e3)")
plt.ylabel("score")
plt.title("DDPG_online")
# Out:
# Text(0.5, 1.0, 'DDPG_online')

# %%
res1 = np.load("buffer_performance_Navi-Acc-Lidar-Obs-Task0_easy-v0_1.npy")
res2 = np.load("buffer_performance_Navi-Acc-Lidar-Obs-Task0_easy-v0_2.npy")
res3 = np.load("buffer_performance_Navi-Acc-Lidar-Obs-Task0_easy-v0_3.npy")
print(res1, res2, res3)
# plt.plot(res0, label="env0")
plt.bar(height=res1, x="seed1")
plt.bar(height=res2, x="seed2")
plt.bar(height=res3, x="seed3")

# plt.legend()
# plt.ylim(-13, 9)
plt.ylabel("score")
plt.title("buffer performance")
# Out:
# [-4.59508232] [5.82173357] [5.82674291]
# Text(0.5, 1.0, 'buffer performance')

# %% [markdown]
# # phi search

# %%
res0 = np.load("BCQ_Navi-Acc-Lidar-Obs-Task0_easy-v0_0_phi_0.0.npy")
res1 = np.load("BCQ_Navi-Acc-Lidar-Obs-Task0_easy-v0_0_phi_0.05.npy")
res2 = np.load("BCQ_Navi-Acc-Lidar-Obs-Task0_easy-v0_0_phi_0.25.npy")
res3 = np.load("BCQ_Navi-Acc-Lidar-Obs-Task0_easy-v0_0_phi_0.5.npy")
res4 = np.load("BCQ_Navi-Acc-Lidar-Obs-Task0_easy-v0_0_phi_1.0.npy")

plt.plot(res4, label="1.0")
plt.plot(res3, label="0.5")
plt.plot(res2, label="0.25")
plt.plot(res1, label="0.05")
plt.plot(res0, label="0.0")
plt.ylim(-13, 9)
plt.legend()
plt.xlabel("timestep (5e3)")
plt.ylabel("score")
plt.title("BCQ (phi search)")
# Out:
# Text(0.5, 1.0, 'BCQ (phi search)')
